# %%
import pandas as pd
import numpy as np

# %%
n_samples = 1000

data = {
    'customer_id': range(1, n_samples + 1),
    'age': np.random.randint(18, 80, n_samples),
    'income': np.random.normal(50000, 20000, n_samples),
    'account_balance': np.random.normal(5000, 3000, n_samples),
    'tenure_months': np.random.randint(1, 120, n_samples),
    'num_products': np.random.randint(1, 5, n_samples),
    'credit_score': np.random.randint(300, 850, n_samples),
    'gender': np.random.choice(['Male', 'Female', 'Other'], n_samples),
    'location': np.random.choice(['Urban', 'Suburban', 'Rural'], n_samples),
    'customer_service_calls': np.random.randint(0, 10, n_samples),
    'churned': np.random.choice([0, 1], n_samples, p=[0.7, 0.3])
}

df = pd.DataFrame(data)

# %%
# Introduce data quality issues
# 1. Missing values
df.loc[np.random.choice(df.index, 50), 'age'] = np.nan
df.loc[np.random.choice(df.index, 80), 'income'] = np.nan
df.loc[np.random.choice(df.index, 30), 'credit_score'] = np.nan
df.loc[np.random.choice(df.index, 20), 'gender'] = np.nan

# 2. Outliers
df.loc[np.random.choice(df.index, 10), 'income'] = np.random.uniform(200000, 500000, 10)
df.loc[np.random.choice(df.index, 5), 'account_balance'] = np.random.uniform(-10000, -5000, 5)

# 3. Inconsistent data
df.loc[np.random.choice(df.index, 10), 'gender'] = df.loc[np.random.choice(df.index, 10), 'gender'].str.lower()

# 4. Duplicates
duplicate_rows = df.sample(5)
df = pd.concat([df, duplicate_rows], ignore_index=True)

print(f"\nDataset created with {len(df)} rows and {len(df.columns)} columns")
print("\nFirst few rows:")
print(df.head())
# Out:
# Dataset created with 1005 rows and 11 columns
#
# First few rows:
#    customer_id   age        income  account_balance  tenure_months  \
# 0            1  43.0  42915.609587      1922.602569              7
# 1            2  26.0  93588.127608      3611.023115            108
# 2            3  30.0  34703.511563      7180.680581             17
# 3            4  65.0  19275.034078      2600.725553             40
# 4            5  57.0  56544.310631      6658.325042             49
#
#    num_products  credit_score  gender  location  customer_service_calls  \
# 0             4         780.0  Female     Urban                       0
# 1             1         776.0   Other  Suburban                       5
# 2             1         428.0   Other     Rural                       7
# 3             4         803.0    Male  Suburban                       0
# 4             1         469.0    Male  Suburban                       7
#
#    churned
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             1005 non-null   int64
#  1   age                     955 non-null    float64
#  2   income                  927 non-null    float64
#  3   account_balance         1005 non-null   float64
#  4   tenure_months           1005 non-null   int64
#  5   num_products            1005 non-null   int64
#  6   credit_score            974 non-null    float64
#  7   gender                  976 non-null    object
#  8   location                1005 non-null   object
#  9   customer_service_calls  1005 non-null   int64
#  10  churned                 1005 non-null   int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 86.5+ KB

# %%
missing_value_columns = ['age', 'income', 'credit_score', 'gender']

# %%
df.describe()
# Out:
#        customer_id         age         income  account_balance  tenure_months  \
# count  1005.000000  955.000000     927.000000      1005.000000    1005.000000
# mean    500.546269   48.950785   53506.739636      5152.889239      60.206965
# std     288.739104   17.447636   37013.717990      3222.659785      33.568847
# min       1.000000   18.000000  -15857.236546     -8628.295194       1.000000
# 25%     250.000000   34.000000   36951.558786      3100.916274      32.000000
# 50%     501.000000   49.000000   50859.624990      5148.167148      60.000000
# 75%     750.000000   63.000000   65021.067748      7385.951136      88.000000
# max    1000.000000   79.000000  473498.966919     15449.437650     119.000000
#
#        num_products  credit_score  customer_service_calls      churned
# count   1005.000000    974.000000             1005.000000  1005.000000
# mean       2.435821    577.876797                4.637811     0.320398
# std        1.124302    156.413809                2.894934     0.466862
# min        1.000000    302.000000                0.000000     0.000000
# 25%        1.000000    440.250000                2.000000     0.000000
# 50%        2.000000    573.000000                5.000000     0.000000
# 75%        3.000000    711.000000                7.000000     1.000000
# max        4.000000    849.000000                9.000000     1.000000

# %%
df.dtypes
# Out:
# customer_id                 int64
# age                       float64
# income                    float64
# account_balance           float64
# tenure_months               int64
# num_products                int64
# credit_score              float64
# gender                     object
# location                   object
# customer_service_calls      int64
# churned                     int64
# dtype: object

# %%
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df))*100

missing_percent_table = pd.DataFrame({"missing_values": missing_values, "missing_percent": missing_percent})

print (missing_percent_table[missing_percent_table["missing_values"] > 0].sort_values("missing_values", ascending=False))
# Out:
#               missing_values  missing_percent
# income                    78         7.761194
# age                       50         4.975124
# credit_score              31         3.084577
# gender                    29         2.885572

# %%
duplicates = df.duplicated().sum()
print (duplicates)

duplicate_values = df[df.duplicated(keep=False)].sort_values("customer_id")
print (duplicate_values)
# Out:
# 5
#       customer_id   age        income  account_balance  tenure_months  \
# 118           119  47.0  31522.079225      9139.843601             55
# 1001          119  47.0  31522.079225      9139.843601             55
# 243           244  62.0  78248.716428      3411.144926             58
# 1000          244  62.0  78248.716428      3411.144926             58
# 701           702  69.0  87646.567657      2715.995149             45
# 1002          702  69.0  87646.567657      2715.995149             45
# 710           711  33.0  50678.860432      4213.261721             10
# 1003          711  33.0  50678.860432      4213.261721             10
# 772           773  36.0  47601.408143      6242.709581             81
# 1004          773  36.0  47601.408143      6242.709581             81
#
#       num_products  credit_score  gender  location  customer_service_calls  \
# 118              3         748.0   Other     Urban                       7
# 1001             3         748.0   Other     Urban                       7
# 243              2         650.0  Female  Suburban                       1
# 1000             2         650.0  Female  Suburban                       1
# 701              3         369.0   Other     Rural                       2
# 1002             3         369.0   Other     Rural                       2
# 710              1         629.0   Other  Suburban                       0
# 1003             1         629.0   Other  Suburban                       0
# 772              4           NaN   Other  Suburban                       0
# 1004             4           NaN   Other  Suburban                       0
#
#       churned
# 118         1
# 1001        1
# 243         1
# 1000        1
# 701         0
# 1002        0
# 710         0
# 1003        0
# 772         0
# 1004        0

# %%
df['gender'] = df['gender'].str.title()
df['location'] = df['location'].str.title()

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns

correlation_matrix = df[numerical_columns].corr()

print (correlation_matrix['churned'].sort_values(ascending= False))
# Out:
# churned                   1.000000
# credit_score              0.086171
# num_products              0.018341
# customer_service_calls    0.001934
# income                   -0.024280
# account_balance          -0.029895
# age                      -0.040228
# customer_id              -0.052341
# tenure_months            -0.058193
# Name: churned, dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
missing_value_columns
# Out:
# ['age', 'income', 'credit_score', 'gender']

# %%
from sklearn.impute import SimpleImputer, KNNImputer

age_imputer = SimpleImputer(strategy='mean')
df['age'] = age_imputer.fit_transform(df[['age']])

income_imputer = SimpleImputer(strategy='median')

df['income'] = income_imputer.fit_transform(df[['income']])

knn_imputer = KNNImputer(n_neighbors=5)
df['credit_score'] = knn_imputer.fit_transform(df[['credit_score']])

gender_imputer = SimpleImputer(strategy='most_frequent')
df['gender'] = gender_imputer.fit_transform(df[['gender']]).ravel()

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             1000 non-null   int64
#  1   age                     1000 non-null   float64
#  2   income                  1000 non-null   float64
#  3   account_balance         1000 non-null   float64
#  4   tenure_months           1000 non-null   int64
#  5   num_products            1000 non-null   int64
#  6   credit_score            1000 non-null   float64
#  7   gender                  1000 non-null   object
#  8   location                1000 non-null   object
#  9   customer_service_calls  1000 non-null   int64
#  10  churned                 1000 non-null   int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 93.8+ KB

# %%
def detect_outliers(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    IQR = q3-q1
    lower_bound = q1-1.5*IQR
    upper_bound = q3 + 1.5*IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers, lower_bound, upper_bound

# %%
numerical_columns = ['age', 'income', 'account_balance', 'tenure_months', 'num_products', 'credit_score', 'customer_service_calls']

# %%
for col in numerical_columns:
    outliers, lower_bound, upper_bound = detect_outliers(df, col)
    df[col] = df[col].clip(lower = lower_bound, upper = upper_bound)

# %%
df.head()
# Out:
#    customer_id   age        income  account_balance  tenure_months  \
# 0            1  43.0  42915.609587      1922.602569              7
# 1            2  26.0  93588.127608      3611.023115            108
# 2            3  30.0  34703.511563      7180.680581             17
# 3            4  65.0  19275.034078      2600.725553             40
# 4            5  57.0  56544.310631      6658.325042             49
#
#    num_products  credit_score  gender  location  customer_service_calls  \
# 0             4         780.0  Female     Urban                       0
# 1             1         776.0   Other  Suburban                       5
# 2             1         428.0   Other     Rural                       7
# 3             4         803.0    Male  Suburban                       0
# 4             1         469.0    Male  Suburban                       7
#
#    churned
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1

# %%
df['age_bucket'] = pd.cut(df['age'],
                          bins = [0, 30, 50, 70, 100],
                          labels = ['Young', 'Mid', 'Senior', 'Old'])

# %%
df.dtypes
# Out:
# customer_id                  int64
# age                        float64
# income                     float64
# account_balance            float64
# tenure_months                int64
# num_products                 int64
# credit_score               float64
# gender                      object
# location                    object
# customer_service_calls       int64
# churned                      int64
# age_bucket                category
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

features_to_scale = ['age', 'income', 'account_balance', 'tenure_months', 'num_products', 'credit_score', 'customer_service_calls']

df[features_to_scale] = scaler.fit_transform(df[features_to_scale])

# %%
df.describe()
# Out:
#        customer_id           age        income  account_balance  \
# count  1000.000000  1.000000e+03  1.000000e+03     1.000000e+03
# mean    500.500000 -2.486900e-16 -1.447731e-16     2.113865e-16
# std     288.819436  1.000500e+00  1.000500e+00     1.000500e+00
# min       1.000000 -1.819186e+00 -2.575452e+00    -2.708514e+00
# 25%     250.750000 -8.199089e-01 -6.388962e-01    -6.603668e-01
# 50%     500.500000  1.320264e-04 -5.046652e-03    -7.158641e-03
# 75%     750.250000  8.259587e-01  6.521408e-01     7.050648e-01
# max    1000.000000  1.766455e+00  2.588696e+00     2.753212e+00
#
#        tenure_months  num_products  credit_score  customer_service_calls  \
# count   1.000000e+03  1.000000e+03  1.000000e+03            1.000000e+03
# mean   -2.664535e-17 -4.973799e-17 -4.121148e-16            6.750156e-17
# std     1.000500e+00  1.000500e+00  1.000500e+00            1.000500e+00
# min    -1.764289e+00 -1.276489e+00 -1.790545e+00           -1.610008e+00
# 25%    -8.413413e-01 -1.276489e+00 -8.556440e-01           -9.176802e-01
# 50%    -7.711080e-03 -3.869496e-01  5.485584e-04            1.208112e-01
# 75%     8.259192e-01  5.025897e-01  8.469793e-01            8.131388e-01
# max     1.748867e+00  1.392129e+00  1.760780e+00            1.505466e+00
#
#           churned
# count  1000.00000
# mean      0.32000
# std       0.46671
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       1.00000
# max       1.00000

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'income', 'account_balance', 'tenure_months',
#        'num_products', 'credit_score', 'gender', 'location',
#        'customer_service_calls', 'churned', 'age_bucket'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

le_encoder = LabelEncoder()

df['age_bucket_encoder'] = le_encoder.fit_transform(df['age_bucket'])

df = pd.get_dummies(df, columns=['gender', 'location'], prefix=['gender', 'location'], drop_first=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'income', 'account_balance', 'tenure_months',
#        'num_products', 'credit_score', 'customer_service_calls', 'churned',
#        'age_bucket', 'age_bucket_encoder', 'gender_Male', 'gender_Other',
#        'location_Suburban', 'location_Urban'],
#       dtype='object')

# %%
x_data = df.drop(['customer_id', 'churned', 'age_bucket'], axis = 1, errors='ignore')
y_data = df['churned']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, train_size=0.2, stratify=Y)

# %%
X_train.shape
# Out:
# (750, 12)

# %%
y_train.shape
# Out:
# (750,)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state= 42, max_depth=10)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print (accuracy_score(y_test, y_pred))
# Out:
# 0.712

# %%
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.94      0.83       181
#            1       0.42      0.12      0.18        69
#
#     accuracy                           0.71       250
#    macro avg       0.58      0.53      0.50       250
# weighted avg       0.65      0.71      0.65       250

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers
# Out:
# /Users/ravireddy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
model =keras.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')

], name='simple_nn')

# %%
model.summary()
# Out:
# Model: "simple_nn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,945 (11.50 KB)
#  Trainable params: 2,945 (11.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    # optimizer = keras.optimizers.Adam(learning_rate=0.001)
    optimizer = keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
    loss = 'binary_crossentropy',
    metrics = ['accuracy',
               keras.metrics.AUC(name='auc'),
               keras.metrics.Precision(name='precision'),
               keras.metrics.Recall(name='recall')]
)

# %%
model_fit = model.fit(
    X_train, y_train,
    validation_data = (X_test, y_test),
    epochs = 100,
    batch_size = 32
)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5943 - auc: 0.5422 - loss: 0.6825 - precision: 0.3785 - recall: 0.3100 - val_accuracy: 0.7240 - val_auc: 0.5097 - val_loss: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6647 - auc: 0.5604 - loss: 0.6302 - precision: 0.3958 - recall: 0.0365 - val_accuracy: 0.7240 - val_auc: 0.5115 - val_loss: 0.5926 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6763 - auc: 0.5184 - loss: 0.6310 - precision: 0.0600 - recall: 4.8401e-04 - val_accuracy: 0.7240 - val_auc: 0.5081 - val_loss: 0.6073 - val_precision: 0.5000 - val_recall: 0.0145
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6905 - auc: 0.5589 - loss: 0.6275 - precision: 0.5262 - recall: 0.0742 - val_accuracy: 0.7240 - val_auc: 0.5097 - val_loss: 0.6074 - val_precision: 0.5000 - val_recall: 0.0435
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6637 - auc: 0.5548 - loss: 0.6258 - precision: 0.2474 - recall: 0.0215 - val_accuracy: 0.7320 - val_auc: 0.5637 - val_loss: 0.5889 - val_precision: 1.0000 - val_recall: 0.0290
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6344 - auc: 0.5693 - loss: 0.6526 - precision: 0.6305 - recall: 0.0842 - val_accuracy: 0.7240 - val_auc: 0.5337 - val_loss: 0.5844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6753 - auc: 0.6341 - loss: 0.6084 - precision: 0.3507 - recall: 0.0343 - val_accuracy: 0.7240 - val_auc: 0.5090 - val_loss: 0.6005 - val_precision: 0.5000 - val_recall: 0.0290
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6687 - auc: 0.5977 - loss: 0.6213 - precision: 0.6201 - recall: 0.0467 - val_accuracy: 0.7240 - val_auc: 0.5996 - val_loss: 0.5877 - val_precision: 0.5000 - val_recall: 0.0290
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6880 - auc: 0.5859 - loss: 0.6137 - precision: 0.5697 - recall: 0.0575 - val_accuracy: 0.7240 - val_auc: 0.5297 - val_loss: 0.5959 - val_precision: 0.5000 - val_recall: 0.0145
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6919 - auc: 0.6705 - loss: 0.5833 - precision: 0.5435 - recall: 0.1255 - val_accuracy: 0.6760 - val_auc: 0.5558 - val_loss: 0.6207 - val_precision: 0.3500 - val_recall: 0.2029
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6844 - auc: 0.6249 - loss: 0.6271 - precision: 0.5583 - recall: 0.3245 - val_accuracy: 0.7200 - val_auc: 0.5550 - val_loss: 0.5882 - val_precision: 0.4444 - val_recall: 0.0580
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6627 - auc: 0.6403 - loss: 0.6201 - precision: 0.6211 - recall: 0.1353 - val_accuracy: 0.7240 - val_auc: 0.5792 - val_loss: 0.5845 - val_precision: 0.5000 - val_recall: 0.0580
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6399 - auc: 0.6088 - loss: 0.6284 - precision: 0.3813 - recall: 0.0804 - val_accuracy: 0.7080 - val_auc: 0.5588 - val_loss: 0.5877 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6798 - auc: 0.6256 - loss: 0.6101 - precision: 0.5616 - recall: 0.1049 - val_accuracy: 0.7040 - val_auc: 0.5869 - val_loss: 0.6000 - val_precision: 0.3913 - val_recall: 0.1304
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6919 - auc: 0.6658 - loss: 0.5923 - precision: 0.6030 - recall: 0.2068 - val_accuracy: 0.7280 - val_auc: 0.5159 - val_loss: 0.5945 - val_precision: 1.0000 - val_recall: 0.0145
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6698 - auc: 0.6478 - loss: 0.6073 - precision: 0.5486 - recall: 0.0875 - val_accuracy: 0.7000 - val_auc: 0.5417 - val_loss: 0.6008 - val_precision: 0.2857 - val_recall: 0.0580
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6822 - auc: 0.6392 - loss: 0.6037 - precision: 0.6980 - recall: 0.0854 - val_accuracy: 0.6840 - val_auc: 0.5514 - val_loss: 0.6165 - val_precision: 0.3214 - val_recall: 0.1304
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6786 - auc: 0.6663 - loss: 0.6018 - precision: 0.6046 - recall: 0.2719 - val_accuracy: 0.6960 - val_auc: 0.5542 - val_loss: 0.6127 - val_precision: 0.2667 - val_recall: 0.0580
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6900 - auc: 0.6752 - loss: 0.6130 - precision: 0.6902 - recall: 0.1722 - val_accuracy: 0.6960 - val_auc: 0.5203 - val_loss: 0.6314 - val_precision: 0.3478 - val_recall: 0.1159
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7007 - auc: 0.6753 - loss: 0.5814 - precision: 0.6019 - recall: 0.2416 - val_accuracy: 0.7040 - val_auc: 0.5674 - val_loss: 0.5975 - val_precision: 0.3333 - val_recall: 0.0725
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6924 - auc: 0.7071 - loss: 0.5793 - precision: 0.6540 - recall: 0.1890 - val_accuracy: 0.7080 - val_auc: 0.5401 - val_loss: 0.6152 - val_precision: 0.4000 - val_recall: 0.1159
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7343 - auc: 0.7012 - loss: 0.5577 - precision: 0.7391 - recall: 0.2254 - val_accuracy: 0.6760 - val_auc: 0.5581 - val_loss: 0.6206 - val_precision: 0.3125 - val_recall: 0.1449
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6881 - auc: 0.6837 - loss: 0.5923 - precision: 0.6210 - recall: 0.2468 - val_accuracy: 0.6880 - val_auc: 0.5525 - val_loss: 0.6166 - val_precision: 0.3043 - val_recall: 0.1014
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7341 - auc: 0.7435 - loss: 0.5448 - precision: 0.7182 - recall: 0.3365 - val_accuracy: 0.6920 - val_auc: 0.5466 - val_loss: 0.6279 - val_precision: 0.3182 - val_recall: 0.1014
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6747 - auc: 0.7028 - loss: 0.5881 - precision: 0.6600 - recall: 0.2483 - val_accuracy: 0.7120 - val_auc: 0.5155 - val_loss: 0.6315 - val_precision: 0.3333 - val_recall: 0.0435
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6881 - auc: 0.6633 - loss: 0.5980 - precision: 0.6484 - recall: 0.1941 - val_accuracy: 0.6800 - val_auc: 0.5227 - val_loss: 0.6169 - val_precision: 0.2963 - val_recall: 0.1159
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6522 - auc: 0.6987 - loss: 0.6135 - precision: 0.6154 - recall: 0.1960 - val_accuracy: 0.7080 - val_auc: 0.5391 - val_loss: 0.6059 - val_precision: 0.3571 - val_recall: 0.0725
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7263 - auc: 0.6986 - loss: 0.5659 - precision: 0.7120 - recall: 0.2713 - val_accuracy: 0.7000 - val_auc: 0.5507 - val_loss: 0.6009 - val_precision: 0.3636 - val_recall: 0.1159
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7222 - auc: 0.7544 - loss: 0.5384 - precision: 0.7522 - recall: 0.2412 - val_accuracy: 0.6880 - val_auc: 0.5306 - val_loss: 0.6254 - val_precision: 0.3636 - val_recall: 0.1739
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7322 - auc: 0.7016 - loss: 0.5572 - precision: 0.7559 - recall: 0.2896 - val_accuracy: 0.7160 - val_auc: 0.5364 - val_loss: 0.6234 - val_precision: 0.4286 - val_recall: 0.0870
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6941 - auc: 0.7111 - loss: 0.5672 - precision: 0.7006 - recall: 0.1829 - val_accuracy: 0.6800 - val_auc: 0.5000 - val_loss: 0.6590 - val_precision: 0.2800 - val_recall: 0.1014
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7464 - auc: 0.6970 - loss: 0.5468 - precision: 0.7522 - recall: 0.3017 - val_accuracy: 0.6720 - val_auc: 0.5189 - val_loss: 0.6577 - val_precision: 0.3243 - val_recall: 0.1739
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7285 - auc: 0.7484 - loss: 0.5406 - precision: 0.6746 - recall: 0.2974 - val_accuracy: 0.6880 - val_auc: 0.5392 - val_loss: 0.6521 - val_precision: 0.3953 - val_recall: 0.2464
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7098 - auc: 0.7403 - loss: 0.5477 - precision: 0.6139 - recall: 0.2788 - val_accuracy: 0.7120 - val_auc: 0.5361 - val_loss: 0.6205 - val_precision: 0.4286 - val_recall: 0.1304
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7179 - auc: 0.7215 - loss: 0.5607 - precision: 0.7046 - recall: 0.3187 - val_accuracy: 0.6800 - val_auc: 0.5594 - val_loss: 0.6360 - val_precision: 0.2963 - val_recall: 0.1159
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7286 - auc: 0.6961 - loss: 0.5604 - precision: 0.7495 - recall: 0.2578 - val_accuracy: 0.7080 - val_auc: 0.5234 - val_loss: 0.6218 - val_precision: 0.3889 - val_recall: 0.1014
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7089 - auc: 0.7474 - loss: 0.5421 - precision: 0.7495 - recall: 0.1813 - val_accuracy: 0.6800 - val_auc: 0.5470 - val_loss: 0.6534 - val_precision: 0.3514 - val_recall: 0.1884
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7048 - auc: 0.7116 - loss: 0.5898 - precision: 0.6755 - recall: 0.3212 - val_accuracy: 0.7160 - val_auc: 0.5513 - val_loss: 0.6159 - val_precision: 0.4167 - val_recall: 0.0725
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7029 - auc: 0.6843 - loss: 0.5834 - precision: 0.7685 - recall: 0.1685 - val_accuracy: 0.6960 - val_auc: 0.5620 - val_loss: 0.6254 - val_precision: 0.3871 - val_recall: 0.1739
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7008 - auc: 0.7379 - loss: 0.5676 - precision: 0.7279 - recall: 0.2504 - val_accuracy: 0.6840 - val_auc: 0.5550 - val_loss: 0.6257 - val_precision: 0.3214 - val_recall: 0.1304
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7184 - auc: 0.6982 - loss: 0.5553 - precision: 0.7465 - recall: 0.2536 - val_accuracy: 0.6800 - val_auc: 0.5436 - val_loss: 0.6389 - val_precision: 0.3333 - val_recall: 0.1594
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6923 - auc: 0.7218 - loss: 0.5528 - precision: 0.6308 - recall: 0.2329 - val_accuracy: 0.6920 - val_auc: 0.5480 - val_loss: 0.6667 - val_precision: 0.3667 - val_recall: 0.1594
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7008 - auc: 0.7311 - loss: 0.5459 - precision: 0.6042 - recall: 0.2489 - val_accuracy: 0.6640 - val_auc: 0.4899 - val_loss: 0.6799 - val_precision: 0.3077 - val_recall: 0.1739
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7087 - auc: 0.7495 - loss: 0.5428 - precision: 0.6390 - recall: 0.3439 - val_accuracy: 0.6920 - val_auc: 0.5188 - val_loss: 0.6880 - val_precision: 0.3571 - val_recall: 0.1449
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7082 - auc: 0.7700 - loss: 0.5414 - precision: 0.6880 - recall: 0.2822 - val_accuracy: 0.6960 - val_auc: 0.5631 - val_loss: 0.6331 - val_precision: 0.3600 - val_recall: 0.1304
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7419 - auc: 0.7602 - loss: 0.5386 - precision: 0.7482 - recall: 0.3560 - val_accuracy: 0.7000 - val_auc: 0.5663 - val_loss: 0.6179 - val_precision: 0.3750 - val_recall: 0.1304
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7401 - auc: 0.7809 - loss: 0.5206 - precision: 0.8706 - recall: 0.3028 - val_accuracy: 0.7040 - val_auc: 0.5502 - val_loss: 0.6370 - val_precision: 0.4000 - val_recall: 0.1449
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7241 - auc: 0.7734 - loss: 0.5223 - precision: 0.6584 - recall: 0.3008 - val_accuracy: 0.6880 - val_auc: 0.5364 - val_loss: 0.6444 - val_precision: 0.3714 - val_recall: 0.1884
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7301 - auc: 0.7847 - loss: 0.5183 - precision: 0.7018 - recall: 0.3056 - val_accuracy: 0.6880 - val_auc: 0.5685 - val_loss: 0.6323 - val_precision: 0.3448 - val_recall: 0.1449
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7087 - auc: 0.7394 - loss: 0.5445 - precision: 0.7121 - recall: 0.2957 - val_accuracy: 0.6960 - val_auc: 0.5839 - val_loss: 0.6173 - val_precision: 0.3600 - val_recall: 0.1304
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7549 - auc: 0.7590 - loss: 0.5142 - precision: 0.7661 - recall: 0.2752 - val_accuracy: 0.6680 - val_auc: 0.5584 - val_loss: 0.6681 - val_precision: 0.3542 - val_recall: 0.2464
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7180 - auc: 0.7434 - loss: 0.5474 - precision: 0.5983 - recall: 0.3539 - val_accuracy: 0.6880 - val_auc: 0.5624 - val_loss: 0.6330 - val_precision: 0.3784 - val_recall: 0.2029
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7023 - auc: 0.7058 - loss: 0.5664 - precision: 0.6226 - recall: 0.2359 - val_accuracy: 0.6920 - val_auc: 0.5568 - val_loss: 0.6334 - val_precision: 0.3667 - val_recall: 0.1594
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7423 - auc: 0.7712 - loss: 0.5234 - precision: 0.7604 - recall: 0.3507 - val_accuracy: 0.7040 - val_auc: 0.5765 - val_loss: 0.6202 - val_precision: 0.3529 - val_recall: 0.0870
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7263 - auc: 0.7663 - loss: 0.5377 - precision: 0.7432 - recall: 0.2734 - val_accuracy: 0.6920 - val_auc: 0.5506 - val_loss: 0.6648 - val_precision: 0.3667 - val_recall: 0.1594
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7413 - auc: 0.7785 - loss: 0.4992 - precision: 0.7308 - recall: 0.3118 - val_accuracy: 0.6800 - val_auc: 0.5669 - val_loss: 0.6904 - val_precision: 0.3659 - val_recall: 0.2174
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7380 - auc: 0.7462 - loss: 0.5385 - precision: 0.7346 - recall: 0.3424 - val_accuracy: 0.6720 - val_auc: 0.5494 - val_loss: 0.7028 - val_precision: 0.3415 - val_recall: 0.2029
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7382 - auc: 0.7744 - loss: 0.5061 - precision: 0.6953 - recall: 0.4221 - val_accuracy: 0.6760 - val_auc: 0.5354 - val_loss: 0.7041 - val_precision: 0.3421 - val_recall: 0.1884
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7308 - auc: 0.8117 - loss: 0.4909 - precision: 0.6660 - recall: 0.4299 - val_accuracy: 0.6960 - val_auc: 0.5538 - val_loss: 0.6651 - val_precision: 0.3793 - val_recall: 0.1594
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7268 - auc: 0.7648 - loss: 0.5213 - precision: 0.7301 - recall: 0.3026 - val_accuracy: 0.6720 - val_auc: 0.5493 - val_loss: 0.6446 - val_precision: 0.3488 - val_recall: 0.2174
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7533 - auc: 0.8096 - loss: 0.4911 - precision: 0.7668 - recall: 0.4303 - val_accuracy: 0.6960 - val_auc: 0.5536 - val_loss: 0.6845 - val_precision: 0.3704 - val_recall: 0.1449
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7117 - auc: 0.7975 - loss: 0.5068 - precision: 0.7064 - recall: 0.3276 - val_accuracy: 0.6880 - val_auc: 0.5617 - val_loss: 0.6854 - val_precision: 0.3548 - val_recall: 0.1594
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7456 - auc: 0.7454 - loss: 0.5344 - precision: 0.6730 - recall: 0.3396 - val_accuracy: 0.6720 - val_auc: 0.5432 - val_loss: 0.6710 - val_precision: 0.3415 - val_recall: 0.2029
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7269 - auc: 0.7604 - loss: 0.5392 - precision: 0.7305 - recall: 0.3724 - val_accuracy: 0.6840 - val_auc: 0.5713 - val_loss: 0.6456 - val_precision: 0.3077 - val_recall: 0.1159
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7191 - auc: 0.7625 - loss: 0.5276 - precision: 0.7122 - recall: 0.3487 - val_accuracy: 0.7160 - val_auc: 0.5188 - val_loss: 0.6613 - val_precision: 0.4545 - val_recall: 0.1449
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7563 - auc: 0.7995 - loss: 0.4768 - precision: 0.7325 - recall: 0.3219 - val_accuracy: 0.6920 - val_auc: 0.5656 - val_loss: 0.6590 - val_precision: 0.3889 - val_recall: 0.2029
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7276 - auc: 0.7884 - loss: 0.4991 - precision: 0.6654 - recall: 0.3665 - val_accuracy: 0.6840 - val_auc: 0.5461 - val_loss: 0.6816 - val_precision: 0.3611 - val_recall: 0.1884
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7765 - auc: 0.8292 - loss: 0.4713 - precision: 0.7820 - recall: 0.4369 - val_accuracy: 0.6880 - val_auc: 0.5684 - val_loss: 0.6710 - val_precision: 0.3784 - val_recall: 0.2029
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7535 - auc: 0.8044 - loss: 0.4910 - precision: 0.7621 - recall: 0.4117 - val_accuracy: 0.6520 - val_auc: 0.5545 - val_loss: 0.6796 - val_precision: 0.2955 - val_recall: 0.1884
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7812 - auc: 0.7999 - loss: 0.4931 - precision: 0.8050 - recall: 0.4189 - val_accuracy: 0.6400 - val_auc: 0.5422 - val_loss: 0.7222 - val_precision: 0.3091 - val_recall: 0.2464
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7346 - auc: 0.7818 - loss: 0.4969 - precision: 0.6703 - recall: 0.3939 - val_accuracy: 0.6880 - val_auc: 0.5679 - val_loss: 0.6693 - val_precision: 0.3636 - val_recall: 0.1739
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7611 - auc: 0.7933 - loss: 0.4892 - precision: 0.7430 - recall: 0.3205 - val_accuracy: 0.6560 - val_auc: 0.5442 - val_loss: 0.6994 - val_precision: 0.3191 - val_recall: 0.2174
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7398 - auc: 0.8105 - loss: 0.4898 - precision: 0.6776 - recall: 0.4618 - val_accuracy: 0.6520 - val_auc: 0.5114 - val_loss: 0.7478 - val_precision: 0.3200 - val_recall: 0.2319
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7536 - auc: 0.8237 - loss: 0.4775 - precision: 0.7531 - recall: 0.4316 - val_accuracy: 0.6480 - val_auc: 0.5241 - val_loss: 0.7128 - val_precision: 0.2432 - val_recall: 0.1304
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7245 - auc: 0.7804 - loss: 0.5042 - precision: 0.6370 - recall: 0.3765 - val_accuracy: 0.6880 - val_auc: 0.5255 - val_loss: 0.6753 - val_precision: 0.3333 - val_recall: 0.1304
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7185 - auc: 0.7755 - loss: 0.5192 - precision: 0.7214 - recall: 0.2858 - val_accuracy: 0.6240 - val_auc: 0.5200 - val_loss: 0.7596 - val_precision: 0.2449 - val_recall: 0.1739
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7704 - auc: 0.7934 - loss: 0.4884 - precision: 0.7473 - recall: 0.4173 - val_accuracy: 0.6360 - val_auc: 0.5465 - val_loss: 0.7290 - val_precision: 0.3036 - val_recall: 0.2464
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7454 - auc: 0.7777 - loss: 0.5426 - precision: 0.7004 - recall: 0.4434 - val_accuracy: 0.6760 - val_auc: 0.5733 - val_loss: 0.6464 - val_precision: 0.3125 - val_recall: 0.1449
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7731 - auc: 0.8270 - loss: 0.4777 - precision: 0.9023 - recall: 0.3981 - val_accuracy: 0.6320 - val_auc: 0.5545 - val_loss: 0.7485 - val_precision: 0.2909 - val_recall: 0.2319
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7402 - auc: 0.7828 - loss: 0.5184 - precision: 0.7047 - recall: 0.4456 - val_accuracy: 0.6720 - val_auc: 0.5460 - val_loss: 0.7062 - val_precision: 0.3143 - val_recall: 0.1594
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7442 - auc: 0.7879 - loss: 0.5061 - precision: 0.7599 - recall: 0.3659 - val_accuracy: 0.6560 - val_auc: 0.5637 - val_loss: 0.7535 - val_precision: 0.3023 - val_recall: 0.1884
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7715 - auc: 0.8098 - loss: 0.4705 - precision: 0.7595 - recall: 0.4267 - val_accuracy: 0.6360 - val_auc: 0.5098 - val_loss: 0.7092 - val_precision: 0.2708 - val_recall: 0.1884
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7374 - auc: 0.8040 - loss: 0.4892 - precision: 0.6794 - recall: 0.4547 - val_accuracy: 0.6840 - val_auc: 0.5368 - val_loss: 0.7000 - val_precision: 0.3077 - val_recall: 0.1159
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7503 - auc: 0.8019 - loss: 0.4832 - precision: 0.7588 - recall: 0.3445 - val_accuracy: 0.6520 - val_auc: 0.5457 - val_loss: 0.6774 - val_precision: 0.2857 - val_recall: 0.1739
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7759 - auc: 0.7999 - loss: 0.4718 - precision: 0.8177 - recall: 0.3695 - val_accuracy: 0.6440 - val_auc: 0.5552 - val_loss: 0.7120 - val_precision: 0.2826 - val_recall: 0.1884
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7187 - auc: 0.7940 - loss: 0.5012 - precision: 0.6614 - recall: 0.3599 - val_accuracy: 0.6840 - val_auc: 0.5523 - val_loss: 0.6742 - val_precision: 0.3333 - val_recall: 0.1449
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7554 - auc: 0.7943 - loss: 0.5141 - precision: 0.8096 - recall: 0.3963 - val_accuracy: 0.6720 - val_auc: 0.5441 - val_loss: 0.7132 - val_precision: 0.3333 - val_recall: 0.1884
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7631 - auc: 0.7943 - loss: 0.4879 - precision: 0.7601 - recall: 0.3859 - val_accuracy: 0.6760 - val_auc: 0.5510 - val_loss: 0.6956 - val_precision: 0.3421 - val_recall: 0.1884
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - auc: 0.7909 - loss: 0.4928 - precision: 0.7267 - recall: 0.3696 - val_accuracy: 0.6680 - val_auc: 0.5256 - val_loss: 0.6922 - val_precision: 0.2812 - val_recall: 0.1304
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7672 - auc: 0.8387 - loss: 0.4659 - precision: 0.8299 - recall: 0.4217 - val_accuracy: 0.6480 - val_auc: 0.5202 - val_loss: 0.7457 - val_precision: 0.2683 - val_recall: 0.1594
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7374 - auc: 0.8009 - loss: 0.4856 - precision: 0.6795 - recall: 0.4491 - val_accuracy: 0.6800 - val_auc: 0.5317 - val_loss: 0.6864 - val_precision: 0.2963 - val_recall: 0.1159
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7788 - auc: 0.8436 - loss: 0.4455 - precision: 0.8224 - recall: 0.4445 - val_accuracy: 0.6400 - val_auc: 0.5165 - val_loss: 0.8162 - val_precision: 0.2162 - val_recall: 0.1159
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7855 - auc: 0.8381 - loss: 0.4493 - precision: 0.8023 - recall: 0.4634 - val_accuracy: 0.6240 - val_auc: 0.5478 - val_loss: 0.7607 - val_precision: 0.2807 - val_recall: 0.2319
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7614 - auc: 0.8204 - loss: 0.4778 - precision: 0.7592 - recall: 0.4676 - val_accuracy: 0.6680 - val_auc: 0.5545 - val_loss: 0.6621 - val_precision: 0.2812 - val_recall: 0.1304
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7789 - auc: 0.8461 - loss: 0.4556 - precision: 0.7817 - recall: 0.4641 - val_accuracy: 0.6760 - val_auc: 0.5602 - val_loss: 0.7075 - val_precision: 0.3500 - val_recall: 0.2029
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7409 - auc: 0.8016 - loss: 0.5083 - precision: 0.7574 - recall: 0.4372 - val_accuracy: 0.6840 - val_auc: 0.5820 - val_loss: 0.6822 - val_precision: 0.3214 - val_recall: 0.1304
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7626 - auc: 0.8470 - loss: 0.4463 - precision: 0.7557 - recall: 0.4445 - val_accuracy: 0.6520 - val_auc: 0.5169 - val_loss: 0.7791 - val_precision: 0.2857 - val_recall: 0.1739
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7896 - auc: 0.8222 - loss: 0.4457 - precision: 0.7365 - recall: 0.4975 - val_accuracy: 0.6320 - val_auc: 0.5452 - val_loss: 0.7464 - val_precision: 0.2745 - val_recall: 0.2029
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7771 - auc: 0.8147 - loss: 0.4725 - precision: 0.7543 - recall: 0.4859 - val_accuracy: 0.6280 - val_auc: 0.5249 - val_loss: 0.7663 - val_precision: 0.2500 - val_recall: 0.1739
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7647 - auc: 0.8166 - loss: 0.4714 - precision: 0.7022 - recall: 0.4567 - val_accuracy: 0.6680 - val_auc: 0.5795 - val_loss: 0.7295 - val_precision: 0.3478 - val_recall: 0.2319
